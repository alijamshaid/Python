# %%
list(open("F:/january.csv"))
# Out:
# ['vehicle Reg\n',
#  'AH 391\n',
#  'C 1010\n',
#  'CU 1998\n',
#  'CU 1998S\n',
#  'CU 2001\n',
#  'CU 2001S\n',
#  'DV 748\n',
#  'FK 274\n',
#  'FK 274S\n',
#  'FK 281\n',
#  'FK 281S\n',
#  'FK 287\n',
#  'FK 287S\n',
#  'FK 290\n',
#  'FK 290S\n',
#  'JF 6376\n',
#  'JF 6378\n',
#  'JF 6382\n',
#  'JP 9592\n',
#  'JU 4733\n',
#  'LES16 644\n',
#  'TLG 550\n',
#  'TLH 150\n',
#  'TLT 123\n',
#  'TLT 261\n',
#  'TLU 261\n',
#  'TLU 363\n',
#  'TLU 417\n',
#  'TLU 561\n',
#  'TLU 562\n',
#  'TLU 663\n',
#  'TLU 792\n',
#  'TLU 861\n',
#  'TLU 961\n',
#  'TLV 250\n',
#  'TLV 361\n',
#  'TLV 450\n',
#  'TLV 592\n',
#  'TLV 870\n',
#  'TLV 872\n',
#  'TLV 878\n',
#  'TLV 879\n',
#  'TLV 881\n',
#  'TLV 882\n',
#  'TLV 883\n',
#  'TLV 892\n',
#  'TLV 992\n',
#  'TLW 292\n',
#  'TLW 350\n',
#  'TLX 061\n',
#  'TLY 361\n',
#  'TLY 863\n',
#  'TLY 903\n',
#  'TLY 961\n',
#  'TLZ 222\n',
#  'TLZ 292\n',
#  'TLZ 322\n',
#  'TLZ 361\n',
#  'TLZ 375\n',
#  'TLZ 392\n',
#  'TLZ 422\n',
# ...
