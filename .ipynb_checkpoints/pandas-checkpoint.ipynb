# %%
import pandas as pd
df=pd.read_csv("F:/ml data/nyc_weather.csv")
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df['EST'][df['Events']=='Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df['WindSpeedMPH'].mean()
# Out:
# 6.892857142857143

# %%
df.fillna(0,inplace=True)
df['WindSpeedMPH'].mean()
# Out:
# 6.225806451612903

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df=pd.read_csv("F:/ml data/weather_data.csv")
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df.shape
# Out:
# (9, 4)

# %%
rows,columns =df.shape
columns
# Out:
# 4

# %%
df[2:5]
# Out:
#         day  temperature  windspeed event
# 2  1/5/2017         28.0        NaN  Snow
# 3  1/6/2017          NaN        7.0   NaN
# 4  1/7/2017         32.0        NaN  Rain

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.day #df['day']
# Out:
# 0     1/1/2017
# 1     1/4/2017
# 2     1/5/2017
# 3     1/6/2017
# 4     1/7/2017
# 5     1/8/2017
# 6     1/9/2017
# 7    1/10/2017
# 8    1/11/2017
# Name: day, dtype: object

# %%
type(df.event)
# Out:
# pandas.core.series.Series

# %%
df[['event','day']]
# Out:
#     event        day
# 0    Rain   1/1/2017
# 1   Sunny   1/4/2017
# 2    Snow   1/5/2017
# 3     NaN   1/6/2017
# 4    Rain   1/7/2017
# 5   Sunny   1/8/2017
# 6     NaN   1/9/2017
# 7  Cloudy  1/10/2017
# 8   Sunny  1/11/2017

# %%
df['temperature'].max()
# Out:
# 40.0

# %%
df.describe()
# Out:
#        temperature  windspeed
# count      5.00000   5.000000
# mean      33.20000   8.400000
# std        4.38178   2.302173
# min       28.00000   6.000000
# 25%       32.00000   7.000000
# 50%       32.00000   8.000000
# 75%       34.00000   9.000000
# max       40.00000  12.000000

# %%
df[df['temperature']>=30]
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 4   1/7/2017         32.0        NaN    Rain
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df[df['temperature']==df.temperature.max()]
# Out:
#          day  temperature  windspeed  event
# 8  1/11/2017         40.0       12.0  Sunny

# %%
df[['day','temperature']][df.temperature==df['temperature'].max()]
# Out:
#          day  temperature
# 8  1/11/2017         40.0

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
df.reset_index(inplace=True)

# %%
df.set_index('event',inplace=True)

# %%
df.loc['Snow']
# Out:
# index                 2
# day            1/5/2017
# temperature          28
# windspeed           NaN
# Name: Snow, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     event  index        day  temperature  windspeed
# 0    Rain      0   1/1/2017         32.0        6.0
# 1   Sunny      1   1/4/2017          NaN        9.0
# 2    Snow      2   1/5/2017         28.0        NaN
# 3     NaN      3   1/6/2017          NaN        7.0
# 4    Rain      4   1/7/2017         32.0        NaN
# 5   Sunny      5   1/8/2017          NaN        NaN
# 6     NaN      6   1/9/2017          NaN        NaN
# 7  Cloudy      7  1/10/2017         34.0        8.0
# 8   Sunny      8  1/11/2017         40.0       12.0

# %%
df=pd.read_excel("F:/ml data/weather_data.xlsx")
df
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-01-02           35          7  Sunny
# 2 2017-01-03           28          2   Snow

# %%
weatherdata={
    'name':['ali','khan','jamshaid'],
    'city':['nowshera','isb','rawalpindi'],
    'marks':[23,67,78]
}
data=pd.DataFrame(weatherdata)
data
# Out:
#        name        city  marks
# 0       ali    nowshera     23
# 1      khan         isb     67
# 2  jamshaid  rawalpindi     78

# %%
weatherdata=(
    ('ali',34,54,'isb'),
    ('waheed',43,42,'rwp'),
    ('jamshaid',34,32,'nowshera')
)
data=pd.DataFrame(weatherdata,columns=['name','age','marks','city'])
data
# Out:
#        name  age  marks      city
# 0       ali   34     54       isb
# 1    waheed   43     42       rwp
# 2  jamshaid   34     32  nowshera

# %%
weatherdata=[
    {'name':'ali','age':34,'marks':54,'city':'isb'},
    {'name':'waheed','age':43,'marks':42,'city':'rwp'},
    {'name':'jamshaid','age':34,'marks':32,'city':'nowshera'}
]
data=pd.DataFrame(weatherdata)
data
# Out:
#        name  age  marks      city
# 0       ali   34     54       isb
# 1    waheed   43     42       rwp
# 2  jamshaid   34     32  nowshera

# %%
df=pd.read_csv("F:/ml data/stock_data.csv",na_values={
    'eps':['not available','n.a.'],
    'revenue':['not available','n.a.',-1],
    'price':['not available','n.a.'],
    'people':['not available','n.a.']
})
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT  -1.00     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %%
weatherdata=pd.DataFrame({
    'name':['ali','khan','jamshaid'],
    'city':['nowshera','isb','rawalpindi'],
    'marks':[23,67,78]
})
studentdata=pd.DataFrame({
    'name':['ali','khan','jamshaid'],
    'city':['skardu','kch','risalpur'],
    'marks':[23,67,78]
})

# %%
with pd.ExcelWriter('F:/ml data/student_weather.xlsx') as writer:
    weatherdata.to_excel(writer,sheet_name="aa")
    studentdata.to_excel(writer,sheet_name="bb")

# %%
df=pd.read_csv('F:/ml data/weather_data.csv',parse_dates=["day"])
new_df=df.fillna(0)

# %%
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          0.0        9.0   Sunny
# 2 2017-01-05         28.0        0.0    Snow
# 3 2017-01-06          0.0        7.0       0
# 4 2017-01-07         32.0        0.0    Rain
# 5 2017-01-08          0.0        0.0   Sunny
# 6 2017-01-09          0.0        0.0       0
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.fillna({
    "temperature":0,
    "windspeed":0,
    "event":"no event"
})
new_df
# Out:
#          day  temperature  windspeed     event
# 0 2017-01-01         32.0        6.0      Rain
# 1 2017-01-04          0.0        9.0     Sunny
# 2 2017-01-05         28.0        0.0      Snow
# 3 2017-01-06          0.0        7.0  no event
# 4 2017-01-07         32.0        0.0      Rain
# 5 2017-01-08          0.0        0.0     Sunny
# 6 2017-01-09          0.0        0.0  no event
# 7 2017-01-10         34.0        8.0    Cloudy
# 8 2017-01-11         40.0       12.0     Sunny

# %%
new_df=df.fillna(method="ffill",limit=1)
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04         32.0        9.0   Sunny
# 2 2017-01-05         28.0        9.0    Snow
# 3 2017-01-06         28.0        7.0    Snow
# 4 2017-01-07         32.0        7.0    Rain
# 5 2017-01-08         32.0        NaN   Sunny
# 6 2017-01-09          NaN        NaN   Sunny
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %% [raw]
# #new_df.set_index('day',inplace=True)
# new_df=new_df.reset_index(inplace=True)
# new_df

# %%
new_df=df.interpolate(method="time")
new_df
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-62-bd51ed073e77> in <module>
# ----> 1 new_df=df.interpolate(method="time")
#       2 new_df
#
# c:\users\wel\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7019
#    7020         if _maybe_transposed_self._data.get_dtype_counts().get("object") == len(
# -> 7021             _maybe_transposed_self.T
#    7022         ):
#    7023             raise TypeError(
#
# c:\users\wel\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in transpose(self, *args, **kwargs)
#    2749         """
#    2750         nv.validate_transpose(args, dict())
# -> 2751         return super().transpose(1, 0, **kwargs)
#    2752
#    2753     T = property(transpose)
#
# ...

# %%
new_df=df.dropna()
new_df
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-64-747ead8ea0f1> in <module>
# ----> 1 new_df=df.dropna()
#       2 new_df
#
# c:\users\wel\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4840                 agg_obj = self.take(indices, axis=agg_axis)
#    4841
# -> 4842             count = agg_obj.count(axis=agg_axis)
#    4843
#    4844             if thresh is not None:
#
# c:\users\wel\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in count(self, axis, level, numeric_only)
#    7815                 # the or any_extension_types is really only hit for single-
#    7816                 # column frames with an extension array
# -> 7817                 result = notna(frame).sum(axis=axis)
#    7818             else:
# ...
