# %%
list(open("F:/january.csv"))
# Out:
# ['average_rate_per_night,latitude,longitude\n',
#  '$82 ,30.309522,-97.73171047\n',
#  '$110 ,30.24429616,-97.77446858\n',
#  '$119 ,30.30038194,-97.77885789\n',
#  '$105 ,30.27752338,-97.71919076\n',
#  '$50 ,30.23294081,-97.58937812\n',
#  '$130 ,30.23038507,-97.76581095\n',
#  '$135 ,30.34285933,-97.73598704\n',
#  '$199 ,30.24962237,-97.72215443\n',
#  '$454 ,30.26594744,-97.74144275\n',
#  '$201 ,30.20515821,-97.8782895\n',
#  '$74 ,30.22363485,-97.78329845\n',
#  '$42 ,30.2759184,-97.71321066\n',
#  '$169 ,30.28283226,-97.70820152\n',
#  '$410 ,30.33816909,-97.82413058\n',
#  '$160 ,30.26611565,-97.7327258\n',
#  '$187 ,30.18835401,-97.81606795\n',
#  '$79 ,30.26704789,-97.68989589\n',
#  '$139 ,30.27456699,-97.7580592\n',
#  '$130 ,30.19237135,-97.7816127\n',
#  '$40 ,30.1925213,-97.73138523\n',
#  '$550 ,30.27640783,-97.62591641\n',
#  '$43 ,30.2474314,-97.77883535\n',
#  '$97 ,30.27661265,-97.73461312\n',
#  '$33 ,30.34622132,-97.6876224\n',
# ...

# %%
data=list(open("F:january.csv"))
print(type(data))
print(data)
data.close()
# Out:
# <class 'list'>
# ...

# %%
data=open("F:/january.csv")
for r in data:
    print(r)
data.close()
# Out:
# average_rate_per_night,latitude,longitude
#
# $82 ,30.309522,-97.73171047
#
# $110 ,30.24429616,-97.77446858
#
# $119 ,30.30038194,-97.77885789
#
# $105 ,30.27752338,-97.71919076
#
# $50 ,30.23294081,-97.58937812
#
# $130 ,30.23038507,-97.76581095
#
# $135 ,30.34285933,-97.73598704
#
# $199 ,30.24962237,-97.72215443
#
# $454 ,30.26594744,-97.74144275
#
# $201 ,30.20515821,-97.8782895
#
# $74 ,30.22363485,-97.78329845
#
# $42 ,30.2759184,-97.71321066
#
# $169 ,30.28283226,-97.70820152
#
# $410 ,30.33816909,-97.82413058
#
# $160 ,30.26611565,-97.7327258
#
# $187 ,30.18835401,-97.81606795
#
# $79 ,30.26704789,-97.68989589
#
# $139 ,30.27456699,-97.7580592
#
# $130 ,30.19237135,-97.7816127
#
# $40 ,30.1925213,-97.73138523
#
# $550 ,30.27640783,-97.62591641
#
# $43 ,30.2474314,-97.77883535
#
# $97 ,30.27661265,-97.73461312
#
# $33 ,30.34622132,-97.6876224
#
# $199 ,30.2708362,-97.74143126
#
# $99 ,30.28254783,-97.82910595
#
# $83 ,30.25230643,-97.77757215
#
# ...

# %%
with open("F:/january.csv") as f:
    content = f.readlines()
    print(type(content))
    print(content)
# Out:
# <class 'list'>
# ...

# %%
with open("F:/january_p.txt",mode='w') as f:
    content = f.write("ali")

# %%
with open("F:/january_p.txt",mode='a') as f:
    content = f.write("juanid \njamshaid \nnowshera")

# %%
with open("F:/january_p2.txt",mode='a+') as f:
    f.write("juanid \njamshaid \nnowshera")
    print(f.readlines())
# Out:
# []

# %%
with open("F:/january_p2.txt",mode='a+') as f:
    f.write("muhammad ali")
    f.seek(0)
    print(f.readlines())
# Out:
# ['juanid \n', 'jamshaid \n', 'nowsheramuhammad ali']

# %%
with open("F:/abc.txt",mode='r+') as f:
    a=list(reversed(f.readlines()))
    b=list(reversed(['A','B','C']))
    c=b+a
    d="".join(c)
    print(d)
# Out:
# CBA

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as mpimg
img=mpimg.imread('F:/visio output/Drawing8.jpg')
print(img.shape)
plt.imshow(img)
# Out:
# (510, 636, 3)

# %%
from PIL import Image
image=Image.open("F:/visio output/Drawing8.jpg")
image.show()

# %%
import cv2
