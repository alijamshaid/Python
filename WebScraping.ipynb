# %%
import urllib
print(dir(urllib))
help(urllib)
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'error', 'parse', 'request', 'response']
# Help on package urllib:
#
# NAME
#     urllib
#
# PACKAGE CONTENTS
#     error
#     parse
#     request
#     response
#     robotparser
#
# FILE
#     c:\users\wel\appdata\local\programs\python\python37-32\lib\urllib\__init__.py

# %%
import urllib.request
print(dir(urllib.request))
help(urllib.request)
# Out:
# ['AbstractBasicAuthHandler', 'AbstractDigestAuthHandler', 'AbstractHTTPHandler', 'BaseHandler', 'CacheFTPHandler', 'ContentTooShortError', 'DataHandler', 'FTPHandler', 'FancyURLopener', 'FileHandler', 'HTTPBasicAuthHandler', 'HTTPCookieProcessor', 'HTTPDefaultErrorHandler', 'HTTPDigestAuthHandler', 'HTTPError', 'HTTPErrorProcessor', 'HTTPHandler', 'HTTPPasswordMgr', 'HTTPPasswordMgrWithDefaultRealm', 'HTTPPasswordMgrWithPriorAuth', 'HTTPRedirectHandler', 'HTTPSHandler', 'MAXFTPCACHE', 'OpenerDirector', 'ProxyBasicAuthHandler', 'ProxyDigestAuthHandler', 'ProxyHandler', 'Request', 'URLError', 'URLopener', 'UnknownHandler', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '__version__', '_cut_port_re', '_ftperrors', '_have_ssl', '_localhost', '_noheaders', '_opener', '_parse_proxy', '_proxy_bypass_macosx_sysconf', '_randombytes', '_safe_gethostbyname', '_thishost', '_url_tempfiles', 'addclosehook', 'addinfourl', 'base64
# ...

# %%
from urllib.request import urlretrieve
url='https://archive.ics.uci.edu/ml/machine-learning-databases/forest-fires/forestfires.csv'
urlretrieve(url,"f.csv")
# Out:
# ('f.csv', <http.client.HTTPMessage at 0x5f62fb0>)

# %%
import pandas as pd
data=pd.read_csv("f.csv",sep=";")
data.head()
# Out:
#   X,Y,month,day,FFMC,DMC,DC,ISI,temp,RH,wind,rain,area
# 0      7,5,mar,fri,86.2,26.2,94.3,5.1,8.2,51,6.7,0,0
# 1      7,4,oct,tue,90.6,35.4,669.1,6.7,18,33,0.9,0,0
# 2    7,4,oct,sat,90.6,43.7,686.9,6.7,14.6,33,1.3,0,0
# 3        8,6,mar,fri,91.7,33.3,77.5,9,8.3,97,4,0.2,0
# 4    8,6,mar,sun,89.3,51.3,102.2,9.6,11.4,99,1.8,0,0

# %%
import csv
with open("f.csv")as f:
    cof=csv.reader(f)
    ppp=[q for q in cof]
print(ppp[0:2])
# Out:
# [['X', 'Y', 'month', 'day', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH', 'wind', 'rain', 'area'], ['7', '5', 'mar', 'fri', '86.2', '26.2', '94.3', '5.1', '8.2', '51', '6.7', '0', '0']]

# %%
df=pd.read_csv(url,sep=";")
print(df.head())
# Out:
#   X,Y,month,day,FFMC,DMC,DC,ISI,temp,RH,wind,rain,area
# 0      7,5,mar,fri,86.2,26.2,94.3,5.1,8.2,51,6.7,0,0
# 1      7,4,oct,tue,90.6,35.4,669.1,6.7,18,33,0.9,0,0
# 2    7,4,oct,sat,90.6,43.7,686.9,6.7,14.6,33,1.3,0,0
# 3        8,6,mar,fri,91.7,33.3,77.5,9,8.3,97,4,0.2,0
# 4    8,6,mar,sun,89.3,51.3,102.2,9.6,11.4,99,1.8,0,0

# %%
import requests
URL="https://www.monster.com/jobs/search/?q=Software-Developer&where=Australia"
page = requests.get(URL)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-71b2ac4fcb58> in <module>
#       2 URL="https://www.monster.com/jobs/search/?q=Software-Developer&where=Australia"
#       3 page = requests.get(URL)
# ----> 4 pprint()
#
# NameError: name 'pprint' is not defined

# %%
import requests
from bs4 import BeautifulSoup
URL = 'https://www.monster.com/jobs/search/?q=Software-Developer&where=Australia'
page = requests.get(URL)
soup = BeautifulSoup(page.content,'html.parser')
results = soup.find(id='ResultsContainer')
job_elems=results.find_all('section',class_='card-content')
for a in job_elems:
    print(a,end='\n')
# Out:
# <section class="card-content" data-jobid="e935f7ad-bf92-4c8e-8c72-c4182d3fecaa" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
# <div class="flex-row">
# <div class="mux-company-logo thumbnail"></div>
# <div class="summary">
# <header class="card-header">
# ...

# %%
import requests
from bs4 import BeautifulSoup
page=requests.get('http://web.mta.info/developers/turnstile.html')
soup=BeautifulSoup(page.content,'html.parser')
print(soup.title)
#i=(soup.find(class_='siteContent').get_text())
#print(i.find(class_='open-section').get_text())
#l=(soup.findAll('a')[36])
#ll=l['href']
#download_url='http://web.mta.info/developers/'+ll
#urllib.request.urlretrieve(download_url,'./’'ll[ll.find('/turnstile_')+1:])
#print(download_url)
# Out:
# <title>mta.info | Turnstile Data</title>

# %%
import pandas
from urllib.request import urlopen
from bs4 import BeautifulSoup
url="http://www.hubertiming.com/results/2017GPTR10K"
#url="https://www.thenews.com.pk/"
html=urlopen(url)
soup=BeautifulSoup(html,'html.parser')
type(soup)
title=soup.get_text()
all_links=soup.find_all('tr')
#print(all_links[:10])
for link in all_links:
    row=(link.find_all("td"))
str_cells=str(row)
type(row)
clean_text=BeautifulSoup(str_cells,'html.parser').get_text()
df=pandas.DataFrame(clean_text)
print(df.head(10))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-c32ebfeeb914> in <module>
#      15 type(row)
#      16 clean_text=BeautifulSoup(str_cells,'html.parser').get_text()
# ---> 17 df=pandas.DataFrame(clean_text)
#      18 print(df.head(10))
#
# c:\users\wel\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     482                 )
#     483             else:
# --> 484                 raise ValueError("DataFrame constructor not properly called!")
#     485
#     486         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html=urlopen("http://pythonscraping.com/pages/page1.html")
bsobj=BeautifulSoup(html.read())
print(bsobj)
# Out:
# <html>
# <head>
# <title>A Useful Page</title>
# </head>
# <body>
# <h1>An Interesting Title</h1>
# <div>
# Lorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.
# </div>
# </body>
# </html>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html=urlopen("http://www.pythonscraping.com/pages/warandpeace.html")
bsobj=BeautifulSoup(html)
print(bsobj.prettify)
#namelist=bsobj.findAll("span",{"class":"green"})
#print(namelist)
#for name in namelist:
 #   print(name.get_text())
#total=(bsobj.findAll(id="text"))
#print(total[0].get_text())
# Out:
# <bound method Tag.prettify of <html>
# <head>
# <style>
# .green{
# 	color:#55ff55;
# }
# .red{
# 	color:#ff5555;
# }
# #text{
# 	width:50%;
# }
# </style>
# </head>
# <body>
# <h1>War and Peace</h1>
# <h2>Chapter 1</h2>
# <div id="text">
# "<span class="red">Well, Prince, so Genoa and Lucca are now just family estates of the
# Buonapartes. But I warn you, if you don't tell me that this means war,
# if you still try to defend the infamies and horrors perpetrated by
# that Antichrist- I really believe he is Antichrist- I will have
# nothing more to do with you and you are no longer my friend, no longer
# my 'faithful slave,' as you call yourself! But how do you do? I see
# I have frightened you- sit down and tell me all the news.</span>"
# <p></p>
# It was in July, 1805, and the speaker was the well-known <span class="green">Anna
# Pavlovna Scherer</span>, maid of honor and favorite of the <span class="green">Empress Marya
# ...

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html=urlopen("http://www.pythonscraping.com/pages/page3.html")
bsobj=BeautifulSoup(html)
#print(bsobj)
print(bsobj.find("img",{"src":"../img/gifts/img1.jpg"}).parent.previous_sibling.get_text())
# Out:
# $15.00

# %%
import bs4
import requests
url = "https://www.mycodingzone.net/blog/english"
data = requests.get(url)
soup = bs4.BeautifulSoup(data.text,'html.parser')
#print(soup.prettify())
#for p in soup.find_all("a"):
#    link=p.get('href')
#    #print(link)
#    if link[0:3] =="../" and link != "#":
#       print('https://www.mycodingzone.net'+link[2:])
#    elif link[0] == "/" and link != "#":
#        print('https://www.mycodingzone.net'+link)
#    elif link != "#":
#        print(link)
# Out:
# https://www.mycodingzone.net/english
# https://www.mycodingzone.net/english
# https://www.mycodingzone.net/tutorials/python/english/getting-started-with-python
# https://www.mycodingzone.net/blog/english
# https://www.mycodingzone.net/videos/english
# https://www.mycodingzone.net/hire/english
# https://www.mycodingzone.net/english
# https://www.mycodingzone.net/hindi
# https://www.mycodingzone.net/hindi-devnagri
# https://www.mycodingzone.net/blog/hindi
# https://www.mycodingzone.net/blog/hindi-devnagri
# https://www.mycodingzone.net/blogpost/english/how-to-install-python-modules-using-wheel
# https://www.mycodingzone.net/blogpost/english/how-to-install-python-modules-using-wheel
# https://www.mycodingzone.net/blogpost/english/pip-is-not-recognized-as-an-internal-or-external-command
# https://www.mycodingzone.net/blogpost/english/pip-is-not-recognized-as-an-internal-or-external-command
# ...

# %%
import bs4
import requests
url = "https://www.youtube.com/channel/UCa5UDzFzpIjJ1VSxCSlQP_g"
data = requests.get(url)
soup = bs4.BeautifulSoup(data.text,'html.parser')
for x in soup.find_all("a"):
    x=(x.get("href"))
    if x[0:3] == "/wa":
        print("https://www.youtube.com/"+x)
# Out:
# https://www.youtube.com//watch?v=wg0nP6gXUgc&list=PL47S5PRS_XOdfT_PNUAmVjJ7M36iqXpJI
# https://www.youtube.com//watch?v=tb-jWOCjo9E&list=PL47S5PRS_XOdCEq37GajvRSLpRwVBmDtE
# https://www.youtube.com//watch?v=6RWFhl3HFFA&list=PL47S5PRS_XOdusDP2EZy_guD_NiCQ9frO
# https://www.youtube.com//watch?v=dzlHErVqmow&list=PL47S5PRS_XOe8dLheR53ichylMMMMX_-T
# https://www.youtube.com//watch?v=vDnSpEBmHfw&list=PL47S5PRS_XOfk3lDNzkbaUN_1mf9ENyo3
# https://www.youtube.com//watch?v=Aur-DAlB1PE&list=PL47S5PRS_XOe02MANXGzrJhMAGGLF6ztY
# https://www.youtube.com//watch?v=CLFKTCEX_gc&list=PL47S5PRS_XOdXtwm-sYJ8dll2y96C0lva
# https://www.youtube.com//watch?v=2MmubHxw1x8&list=PL47S5PRS_XOdCri8z9q_PwTgPUUVIVUsp
# https://www.youtube.com//watch?v=qm41bKO1V3k&list=PL47S5PRS_XOe8CYoKqLuOo_GEOE1kWMKW
# https://www.youtube.com//watch?v=tNyRl2DxSHo&list=PL47S5PRS_XOcYlhjZQpdteumRNDdVtEb6
# https://www.youtube.com//watch?v=tlW08a8SiH4&list=PL47S5PRS_XOf6T1BpSh9UJ1-kNrVBd_iF
# ...
